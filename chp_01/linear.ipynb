# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = [np.random.rand() * 10 for _ in range(50)]
y_train = [val for val in x_train]

print(x_train)
print("-" * 100)
print(y_train)
# Out:
# [0.22687601543317948, 8.56386787592324, 1.0884761889018324, 9.460083336607465, 8.36623638142399, 3.6490666090456303, 9.824988298833436, 3.594904775539962, 2.374662487855538, 8.504246068158658, 1.1507276616176487, 3.7841304817665664, 5.957025431305082, 2.0544191034887316, 9.017204868023988, 7.626523403307871, 5.090626325158276, 1.5806237601386752, 0.20792005994175522, 6.229356065556253, 4.568357771242089, 6.5590926727742, 2.0215948032391715, 2.250000286547783, 9.46312005525643, 5.567254466070011, 4.231225835163906, 8.671484318411713, 6.435258640103571, 5.980764235521252, 5.068200263395437, 2.2994415312614103, 5.8658240214196535, 0.7701448961401047, 4.570184475738209, 7.678612094431316, 5.939412637960565, 6.730257424210785, 2.772256432615534, 9.410188126143623, 3.7740410665930635, 0.31934116467043805, 3.7962161565110906, 0.5220103942273724, 9.334450126989346, 9.752705867203103, 4.286562434721015, 6.816120664970608, 3.817388344599072, 3.472222468274373]
# ...

# %%
plt.plot(x_train, y_train)
plt.show()
